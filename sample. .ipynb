# %%
import pandas as pd
df=pd.read_csv('floor_predictions_final.csv')
print(df.head())
# Out:
#    cluster_id  n_points     height         area    density  low_frac  n_gaps  \
# 0           0     78447  12.954828  6203.666275  12.645264  0.530120       3
# 1           1     98270  14.528693  5426.766211  18.108390  0.790000       5
# 2           2     98672  13.155070  6359.826707  15.514888  0.658228       7
# 3           3     11649  13.701692   364.360127  31.971116  0.505747       2
# 4           5     24398   8.321307  2589.050556   9.423532  0.753425       1
#
#    floor_est_initial  floor_label  floors_pred  usable_area_per_floor
# 0                  3            3            3             971.658573
# 1                  5            5            5             227.924181
# 2                  5            5            5             434.722332
# 3                  3            3            3              60.028680
# 4                  2            2            2             319.198014
